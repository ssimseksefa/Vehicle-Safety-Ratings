# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Reading data

# %%
# Reading the filtered and final crash files for each year

crash_2016 = pd.read_csv('data/crash/crash_2016.csv')
crash_2017 = pd.read_csv('data/crash/crash_2017.csv')
crash_2018 = pd.read_csv('data/crash/crash_2018.csv')

crash_list = [crash_2016, crash_2017, crash_2018]
crash = pd.concat(crash_list)

# %%
pd.set_option('display.max_columns', 200) # to display all 51 columns 
crash.head()
# Out:
#         casenum  veh_no  ve_forms  numoccs  month  hour  minute  harm_ev  \
# 0  201600014311       1         2        1      1    12      33       12
# 1  201600014311       2         2        1      1    12      33       12
# 2  201600014315       1         2        1      1    19      32       12
# 3  201600014315       2         2        3      1    19      32       12
# 4  201600014316       1         1        1      1     6      20       43
#
#    man_coll           vin  trav_sp  rollover  rolinloc  deformed  fire_exp  \
# 0         7  1HGCG16532A0       20         0         0         4         0
# 1         7  4T3ZA3BB5DU0       20         0         0         4         0
# 2         2  1GTEC14Z8SZ5       15         0         0         6         0
# 3         2  1FMZU67KX4UB       25         0         0         6         0
# 4         0  1G8ZK52702Z1       50         1         1         6         0
#
#    dr_zip  speedrel  vtrafway  vnum_lan  vspd_lim  valign  vprofile  vsurcond  \
# 0   81007         0         8         8        30       1         1         1
# 1   81004         0         8         8        30       1         1         1
# 2   81007         0         8         8        30       1         2         1
# 3   81005         0         8         8        30       1         2         1
# 4   81004         0         5         6        50       1         1         1
#
#    acc_type  bdytyp_im  mdlyr_im  impact1_im  vevent_im  pcrash1_im  \
# 0        46          4      2002           1         12          15
# 1        45          5      2013           9         12           1
# 2        68         31      1995          12         12          11
# 3        69         30      2004          12         12           1
# 4         2          4      2002          11          1           1
#
#    mxvsev_im  numinj_im  v_alch_im    make                model  vinyear  \
# 0          0          0          2   HONDA               ACCORD   2002.0
# 1          0          0          2  TOYOTA                VENZA   2013.0
# 2          1          1          2     GMC               SIERRA   1995.0
# 3          1          3          2    FORD  EXPLORER SPORT TRAC   2004.0
# 4          3          1          2  SATURN                  SL2   2002.0
#
#     trim                make_model  mfactor  weathr_im  lgtcon_im  \
# 0     EX              HONDA ACCORD        0          1          1
# 1     LE              TOYOTA VENZA        0          1          1
# 2  C1500                GMC SIERRA        0          1          3
# 3    NaN  FORD EXPLORER SPORT TRAC        0          1          3
# 4    NaN                SATURN SL2        0          1          3
#
#    inj_sev_rate  weighted_inj_sev_rate
# 0             0                    3.0
# 1             0                    3.0
# 2            25                   25.0
# 3            25                   25.0
# 4            75                   75.0

# %%
plt.plot(crash.mdlyr_im.value_counts()[crash.mdlyr_im.value_counts().index.isin(range(1995,2020))].sort_index().index, 
         crash.mdlyr_im.value_counts()[crash.mdlyr_im.value_counts().index.isin(range(1995,2020))].sort_index())

# %% [markdown]
# #### Finding 1:

# %% [markdown]
# The number of 2008-2011 year vehicles are lower than expected. It must be related with financial crisis of 2007-2008 and its long-term effects

# %% [markdown]
# ## Damage to people / first level

# %% [markdown]
# #### Quantizing the severity of damage to people in a vehicle

# %% [markdown]
# Here, I need to create a column which will show the severity of damage from 100 (fatal) to 0 (no injury)

# %% [markdown]
# Assumption: Injured, Severity Unknown must be in between "Minor Injury" (50) and "Serious Injury" (75). Hence it is quantized as 65

# %%
# The numbers of each injury severity levels
crash.inj_sev_rate.value_counts()
# Out:
# 0      155288
# 25      36457
# 50      18649
# 75      12560
# 100      1984
# 65        798
# Name: inj_sev_rate, dtype: int64

# %% [markdown]
# #### Grouping by make_models

# %%
avg_inj_sev = crash[['make_model', 'inj_sev_rate', 'vinyear']].groupby('make_model').agg(['mean', 'count'])
avg_inj_sev.columns = ['avg_inj_sev', 'number_of_accidents', 'avg_mod_year', 'count']
avg_inj_sev = avg_inj_sev.drop(columns='count')
avg_inj_sev.avg_mod_year = round(avg_inj_sev.avg_mod_year, 1)
avg_inj_sev = avg_inj_sev.sort_values('avg_inj_sev',ascending=True)
avg_inj_sev = avg_inj_sev.reset_index()

# %% [markdown]
# #### Question:

# %% [markdown]
# What should be the minimum sample number to be able to speak statistically a make/model is safe or not?

# %%
# Sample number of specific make/model
n = 45
avg_inj_sev[avg_inj_sev.number_of_accidents>n].head()
# Out:
#          make_model  avg_inj_sev  number_of_accidents  avg_mod_year
# 170  SATURN OUTLOOK     3.125000                   48        2007.9
# 200    INFINITI QX4     5.851064                   47        2000.5
# 206         BMW 525     6.250000                   56        2003.8
# 221       HUMMER H3     6.701031                   97        2006.8
# 233   HONDA INSIGHT     7.236842                   76        2010.4

# %% [markdown]
# #### Problem:

# %% [markdown]
# This maximum severity of injury shows only the severity of the most injured person in a vehicle.
#
# Another important factor is what percentage of people in vehicle got injured?

# %% [markdown]
# #### Possible solution:

# %% [markdown]
# Creating weighted severity of injury: inury severity * number of injured / number of occupants

# %%
avg_wgh_inj_sev = crash[['make_model', 'weighted_inj_sev_rate', 'vinyear']].groupby('make_model').agg(['mean', 'count'])
avg_wgh_inj_sev.columns = ['avg_wgh_inj_sev', 'number_of_accidents', 'avg_mod_year', 'count']
avg_wgh_inj_sev = avg_wgh_inj_sev.drop(columns='count')
avg_wgh_inj_sev.avg_mod_year = round(avg_wgh_inj_sev.avg_mod_year, 1)
avg_wgh_inj_sev = avg_wgh_inj_sev.sort_values('avg_wgh_inj_sev',ascending=True)
avg_wgh_inj_sev = avg_wgh_inj_sev.reset_index()

# %%
avg_wgh_inj_sev[avg_wgh_inj_sev.number_of_accidents>n].head()
# Out:
#          make_model  avg_wgh_inj_sev  number_of_accidents  avg_mod_year
# 169  SATURN OUTLOOK         4.968750                   48        2007.9
# 190    INFINITI QX4         6.656028                   47        2000.5
# 227         BMW 525         8.288690                   56        2003.8
# 237       HUMMER H3         8.657216                   97        2006.8
# 239        RAM 2500         8.970760                  228        2015.2

# %% [markdown]
# I need to go deeper since it is obvious that not all the accident conditions are exact same. I should compare similiar conditions and results in order to see more accurate. Hence I need to create another level which will show the condition in which crash occured.

# %% [markdown]
# ## Crash condition / second level

# %%
# Creating new column to display and categorize travel speeds as multiples of 5 i.e. [0-5)-> 0, [5-10)-> 5, [10-15)-> 10, ... mph 

# speed_interval = pd.interval_range(start=0, freq=5, end=150, closed='left')
# speed_list=[]
# for i in range(0,150,5): speed_list.append(i)
# crash['travel_speed'] = np.where(crash.trav_sp==997, 
#                                                        160,
#                                                        pd.cut(crash.trav_sp, bins=speed_interval).apply(lambda x: x.left)
#                                                       )
# crash.travel_speed = crash.travel_speed.fillna(999).astype(int)

# Doing the same work:

crash['travel_speed'] = (crash.trav_sp/5).astype(int)*5

# %%
# The number of vehicles older than 1989 is lower than 100, so I want to group them to see if there is a correlation between year and damage
# Creating new column to display model years of old cars as group:
# [:,1970)-> 1960, [1970,1980)-> 1970, [1980-1990)->1980

crash['year'] = np.where(crash.mdlyr_im<1990,
                                               (crash.mdlyr_im/10).astype(int)*10,
                                               crash.mdlyr_im.astype(int) )

# %% [markdown]
# ** The conditions that may have huge impact on the damage resulted. I want to see their effects and then isolate that effect if I could.**

# %%
crash.columns
# Out:
# Index(['casenum', 'veh_no', 've_forms', 'numoccs', 'month', 'hour', 'minute',
#        'harm_ev', 'man_coll', 'vin', 'trav_sp', 'rollover', 'rolinloc',
#        'deformed', 'fire_exp', 'dr_zip', 'speedrel', 'vtrafway', 'vnum_lan',
#        'vspd_lim', 'valign', 'vprofile', 'vsurcond', 'acc_type', 'bdytyp_im',
#        'mdlyr_im', 'impact1_im', 'vevent_im', 'pcrash1_im', 'mxvsev_im',
#        'numinj_im', 'v_alch_im', 'make', 'model', 'vinyear', 'trim',
#        'make_model', 'mfactor', 'weathr_im', 'lgtcon_im', 'inj_sev_rate',
#        'weighted_inj_sev_rate', 'travel_speed', 'year'],
#       dtype='object')

# %%
condition_list = ['weathr_im', 'lgtcon_im',
                  'mfactor', 
                  'vevent_im', 'impact1_im', 
                  'year', 
                  'travel_speed', 
                  'v_alch_im', 
                  'vsurcond' ]

crush_type_list = ['acc_type', 'rollover', 'deformed', 'fire_exp']

condition_list+crush_type_list
# Out:
# ['weathr_im',
#  'lgtcon_im',
#  'mfactor',
#  'vevent_im',
#  'impact1_im',
#  'year',
#  'travel_speed',
#  'v_alch_im',
#  'vsurcond',
#  'acc_type',
#  'rollover',
#  'deformed',
#  'fire_exp']

# %% [markdown]
# I will create a dataframe which contains all groups of all these categories. Hence I first created a function which group by by a category and returns the counts and avgerage severity of injury for each groups(which is code for each category/data elemnts). Then I merged these data for all conditions.

# %%
# This is the average of all conditions in 2016
overall_avg = crash.weighted_inj_sev_rate.describe()[['mean', 'min', '25%', '50%', '75%', 'max']].mean()

# Minimum number of crushes in order to be able to safely say that a condition is more dangerous or safe 
min_cnt = 33

def category_avg(category):
    condition = crash[[category, 'weighted_inj_sev_rate']].groupby(category).describe()
    condition.columns = [category+'_count', 'mean', 'std', 'min', '1q', '2q', '3q', 'max']
    condition[category+'_avg_severity'] = condition[['mean', 'min', '1q', '2q', '3q', 'max']].mean(axis=1)
    condition[category+'_relative_severity'] = (condition[category+'_avg_severity']-overall_avg).round(2)
    condition = condition.drop(columns=[category+'_avg_severity', 'mean', 'std', 'min', '1q', '2q', '3q', 'max']).reset_index()
    condition = condition[condition[category+'_count']>min_cnt].reset_index(drop=True)
    
    return condition

conditions = pd.DataFrame()

for i in range(len(condition_list+crush_type_list)):
    
    conditions = pd.merge(conditions, category_avg((condition_list+crush_type_list)[i]), left_index=True, right_index=True, how='outer')
    
conditions.head()
# Out:
#    weathr_im  weathr_im_count  weathr_im_relative_severity  lgtcon_im  \
# 0        1.0         164313.0                        -0.03        1.0
# 1        2.0          21615.0                         0.11        2.0
# 2        3.0            339.0                         0.24        3.0
# 3        4.0           3543.0                        -2.28        4.0
# 4        5.0            841.0                         1.18        5.0
#
#    lgtcon_im_count  lgtcon_im_relative_severity  mfactor  mfactor_count  \
# 0         165623.0                        -0.15      0.0       201622.0
# 1          18357.0                         1.19      1.0         1014.0
# 2          32203.0                         0.14      2.0          749.0
# 3           3285.0                         0.38      3.0          147.0
# 4           5154.0                        -1.49      4.0           34.0
#
#    mfactor_relative_severity  vevent_im  vevent_im_count  \
# 0                       0.00        1.0           4559.0
# 1                       6.07        2.0            172.0
# 2                      -3.94        3.0             56.0
# 3                      -3.42        5.0             66.0
# 4                      -3.37        7.0             42.0
#
#    vevent_im_relative_severity  impact1_im  impact1_im_count  \
# 0                        25.46         0.0            1775.0
# 1                        16.26         1.0           10162.0
# 2                         6.28         2.0            3101.0
# 3                        18.46         3.0            6509.0
# 4                       -12.69         4.0            2008.0
#
#    impact1_im_relative_severity    year  year_count  year_relative_severity  \
# 0                         15.86  1970.0        82.0                    4.48
# 1                         -2.14  1980.0      1012.0                    0.92
# 2                         -2.95  1990.0       305.0                    1.01
# 3                          0.46  1991.0       412.0                    1.11
# 4                         -2.41  1992.0       522.0                    0.83
#
#    travel_speed  travel_speed_count  travel_speed_relative_severity  \
# 0           0.0             41393.0                           -1.79
# 1           5.0              8876.0                           -4.54
# 2          10.0              9212.0                           -4.40
# 3          15.0              7199.0                           -4.18
# 4          20.0              6404.0                           -4.20
#
#    v_alch_im  v_alch_im_count  v_alch_im_relative_severity  vsurcond  \
# 0        1.0           6277.0                         15.6       0.0
# 1        2.0         219459.0                         -0.1       1.0
# 2        NaN              NaN                          NaN       2.0
# 3        NaN              NaN                          NaN       3.0
# 4        NaN              NaN                          NaN       4.0
#
#    vsurcond_count  vsurcond_relative_severity  acc_type  acc_type_count  \
# 0          6233.0                       -4.54         0           362.0
# 1        180873.0                        0.03         1          6403.0
# 2         30742.0                        0.13         2          2847.0
# 3          2381.0                       -2.34         3          1046.0
# 4          2175.0                        0.02         4            34.0
#
#    acc_type_relative_severity  rollover  rollover_count  \
# 0                        0.63       0.0        219313.0
# 1                       11.14       1.0          2388.0
# 2                       10.52       2.0           390.0
# 3                        1.02       9.0          3645.0
# 4                        9.07       NaN             NaN
#
#    rollover_relative_severity  deformed  deformed_count  \
# 0                       -0.16       0.0          4979.0
# 1                       25.86       2.0         63472.0
# 2                       21.05       4.0         51827.0
# 3                       25.41       6.0         78486.0
# 4                         NaN       8.0         25596.0
#
#    deformed_relative_severity  fire_exp  fire_exp_count  \
# 0                       -5.03       0.0        225299.0
# 1                       -4.95       1.0           437.0
# 2                       -4.56       NaN             NaN
# 3                        9.87       NaN             NaN
# 4                       -4.31       NaN             NaN
#
#    fire_exp_relative_severity
# 0                       -0.01
# 1                       22.23
# 2                         NaN
# 3                         NaN
# 4                         NaN

# %% [markdown]
# This 'conditions' dataframe will be used like lookup table.

# %%
def condition_rate(category):
    return conditions[[category, category+'_relative_severity']].dropna()

crash['crash_codition'] = 0

for i in range(len(condition_list)):
    
    crash = pd.merge(crash, condition_rate(condition_list[i]), on= condition_list[i], how='left')
    
    crash.crash_codition = crash.crash_codition + crash[condition_list[i]+'_relative_severity'].fillna(0)
    
    crash = crash.drop(columns=condition_list[i]+'_relative_severity')
    
# Crash condition normalization:
crash.crash_codition = 10-20*(crash.crash_codition-crash.crash_codition.min())/(crash.crash_codition.max()-crash.crash_codition.min())

crash.head()
# Out:
#         casenum  veh_no  ve_forms  numoccs  month  hour  minute  harm_ev  \
# 0  201600014311       1         2        1      1    12      33       12
# 1  201600014311       2         2        1      1    12      33       12
# 2  201600014315       1         2        1      1    19      32       12
# 3  201600014315       2         2        3      1    19      32       12
# 4  201600014316       1         1        1      1     6      20       43
#
#    man_coll           vin  trav_sp  rollover  rolinloc  deformed  fire_exp  \
# 0         7  1HGCG16532A0       20         0         0         4         0
# 1         7  4T3ZA3BB5DU0       20         0         0         4         0
# 2         2  1GTEC14Z8SZ5       15         0         0         6         0
# 3         2  1FMZU67KX4UB       25         0         0         6         0
# 4         0  1G8ZK52702Z1       50         1         1         6         0
#
#    dr_zip  speedrel  vtrafway  vnum_lan  vspd_lim  valign  vprofile  vsurcond  \
# 0   81007         0         8         8        30       1         1         1
# 1   81004         0         8         8        30       1         1         1
# 2   81007         0         8         8        30       1         2         1
# 3   81005         0         8         8        30       1         2         1
# 4   81004         0         5         6        50       1         1         1
#
#    acc_type  bdytyp_im  mdlyr_im  impact1_im  vevent_im  pcrash1_im  \
# 0        46          4      2002           1         12          15
# 1        45          5      2013           9         12           1
# 2        68         31      1995          12         12          11
# 3        69         30      2004          12         12           1
# 4         2          4      2002          11          1           1
#
#    mxvsev_im  numinj_im  v_alch_im    make                model  vinyear  \
# 0          0          0          2   HONDA               ACCORD   2002.0
# 1          0          0          2  TOYOTA                VENZA   2013.0
# 2          1          1          2     GMC               SIERRA   1995.0
# 3          1          3          2    FORD  EXPLORER SPORT TRAC   2004.0
# 4          3          1          2  SATURN                  SL2   2002.0
#
#     trim                make_model  mfactor  weathr_im  lgtcon_im  \
# 0     EX              HONDA ACCORD        0          1          1
# 1     LE              TOYOTA VENZA        0          1          1
# 2  C1500                GMC SIERRA        0          1          3
# 3    NaN  FORD EXPLORER SPORT TRAC        0          1          3
# 4    NaN                SATURN SL2        0          1          3
#
#    inj_sev_rate  weighted_inj_sev_rate  travel_speed  year  crash_codition
# 0             0                    3.0            20  2002        5.612449
# 1             0                    3.0            20  2013        5.185215
# 2            25                   25.0            15  1995        5.097208
# 3            25                   25.0            25  2004        4.932395
# 4            75                   75.0            50  2002       -0.500040

# %%
crash['damage_over_condition'] = crash.weighted_inj_sev_rate + 2*crash.crash_codition

crash.damage_over_condition = 100*(crash.damage_over_condition-crash.damage_over_condition.min())/(crash.damage_over_condition.max()-crash.damage_over_condition.min())

crash['safety_rate'] = 100-crash.damage_over_condition

crash.head()
# Out:
#         casenum  veh_no  ve_forms  numoccs  month  hour  minute  harm_ev  \
# 0  201600014311       1         2        1      1    12      33       12
# 1  201600014311       2         2        1      1    12      33       12
# 2  201600014315       1         2        1      1    19      32       12
# 3  201600014315       2         2        3      1    19      32       12
# 4  201600014316       1         1        1      1     6      20       43
#
#    man_coll           vin  trav_sp  rollover  rolinloc  deformed  fire_exp  \
# 0         7  1HGCG16532A0       20         0         0         4         0
# 1         7  4T3ZA3BB5DU0       20         0         0         4         0
# 2         2  1GTEC14Z8SZ5       15         0         0         6         0
# 3         2  1FMZU67KX4UB       25         0         0         6         0
# 4         0  1G8ZK52702Z1       50         1         1         6         0
#
#    dr_zip  speedrel  vtrafway  vnum_lan  vspd_lim  valign  vprofile  vsurcond  \
# 0   81007         0         8         8        30       1         1         1
# 1   81004         0         8         8        30       1         1         1
# 2   81007         0         8         8        30       1         2         1
# 3   81005         0         8         8        30       1         2         1
# 4   81004         0         5         6        50       1         1         1
#
#    acc_type  bdytyp_im  mdlyr_im  impact1_im  vevent_im  pcrash1_im  \
# 0        46          4      2002           1         12          15
# 1        45          5      2013           9         12           1
# 2        68         31      1995          12         12          11
# 3        69         30      2004          12         12           1
# 4         2          4      2002          11          1           1
#
#    mxvsev_im  numinj_im  v_alch_im    make                model  vinyear  \
# 0          0          0          2   HONDA               ACCORD   2002.0
# 1          0          0          2  TOYOTA                VENZA   2013.0
# 2          1          1          2     GMC               SIERRA   1995.0
# 3          1          3          2    FORD  EXPLORER SPORT TRAC   2004.0
# 4          3          1          2  SATURN                  SL2   2002.0
#
#     trim                make_model  mfactor  weathr_im  lgtcon_im  \
# 0     EX              HONDA ACCORD        0          1          1
# 1     LE              TOYOTA VENZA        0          1          1
# 2  C1500                GMC SIERRA        0          1          3
# 3    NaN  FORD EXPLORER SPORT TRAC        0          1          3
# 4    NaN                SATURN SL2        0          1          3
#
#    inj_sev_rate  weighted_inj_sev_rate  travel_speed  year  crash_codition  \
# 0             0                    3.0            20  2002        5.612449
# 1             0                    3.0            20  2013        5.185215
# 2            25                   25.0            15  1995        5.097208
# 3            25                   25.0            25  2004        4.932395
# 4            75                   75.0            50  2002       -0.500040
#
#    damage_over_condition  safety_rate
# 0              18.787105    81.212895
# 1              18.081895    81.918105
# 2              36.093666    63.906334
# 3              35.821619    64.178381
# 4              68.120623    31.879377

# %%
avg_safety_rate = crash[['make', 'safety_rate', 'vinyear', 'weighted_inj_sev_rate']].groupby('make').agg(['mean', 'count'])
avg_safety_rate.columns = ['avg_safety_rate', 'number_of_accidents', 'avg_mod_year', 'count', 'weighted_inj_sev_rate', 'cnt']
avg_safety_rate = avg_safety_rate.drop(columns=['count', 'cnt'])
avg_safety_rate.avg_mod_year = round(avg_safety_rate.avg_mod_year, 1)
avg_safety_rate = avg_safety_rate.sort_values('avg_safety_rate',ascending=True)
avg_safety_rate = avg_safety_rate.reset_index()
avg_safety_rate[avg_safety_rate.number_of_accidents>2].head()
# Out:
#              make  avg_safety_rate  number_of_accidents  avg_mod_year  \
# 2         BENTLEY        57.832286                    8        2011.0
# 3      ALFA ROMEO        64.083409                    5        2017.4
# 5           SMART        65.664210                   36        2011.7
# 6          DAEWOO        65.984354                    8        2001.5
# 7             GEO        67.934177                   95        1994.8
# 8        PLYMOUTH        68.511736                  141        1997.5
# 9          DATSUN        71.045091                    5        1983.2
# 10     OLDSMOBILE        71.159185                  587        1998.3
# 11          ISUZU        71.900804                  249        2000.0
# 12         NISSAN        72.496299                23741        2011.2
# 13            KIA        72.508689                 7962        2012.7
# 14           MINI        72.520006                  336        2011.1
# 15           FIAT        72.533317                  149        2014.2
# 16     MITSUBISHI        72.553136                 1952        2008.1
# 17          BUICK        72.653745                 3537        2006.3
# 18         JAGUAR        72.833060                  215        2007.4
# 19        MERCURY        72.889246                 1536        2002.8
# 20        PONTIAC        72.921646                 2573        2004.2
# 21         SATURN        72.971552                 1456        2004.2
# 22       CHRYSLER        73.006519                 4900        2009.1
# 23       MASERATI        73.078471                   36        2014.0
# 24      CHEVROLET        73.107475                29184        2008.3
# 25        HYUNDAI        73.167841                10375        2012.1
# 26        GENESIS        73.342952                   17        2017.3
# 27          MAZDA        73.512392                 3613        2009.2
# 28          HONDA        73.520153                21440        2008.6
# 29     VOLKSWAGEN        73.613133                 3579        2010.7
# 30       CADILLAC        73.685215                 2179        2007.9
# 31           FORD        73.775451                29677        2008.0
# 32            GMC        73.854595                 5110        2007.4
# 33        LINCOLN        73.885838                 1328        2006.2
# 34    ROLLS-ROYCE        73.919597                    3        2006.0
# 35         TOYOTA        73.930195                31547        2009.4
# 36         SUBARU        73.930280                 2802        2011.1
# 37          DODGE        73.977910                11214        2007.9
# 38         SUZUKI        74.128405                  477        2006.0
# 39           JEEP        74.165767                 6917        2009.2
# 40  MERCEDES-BENZ        74.321533                 2455        2009.8
# 41          ACURA        74.483806                 2365        2007.3
# 42          VOLVO        74.534325                  905        2006.3
# 43       INFINITI        74.609816                 1875        2009.0
# 44            BMW        74.826930                 2555        2009.3
# 45          LEXUS        74.837062                 3441        2008.8
# 46           SAAB        75.120636                  119        2004.3
# 47          TESLA        75.276730                   61        2015.6
# 48     LAND ROVER        75.602190                  321        2010.5
# 49           AUDI        75.635017                  987        2010.9
# 50         HUMMER        76.309633                  148        2006.2
# 51            RAM        76.314877                 1334        2015.1
# 52        PORSCHE        77.268170                  153        2010.1
# 53          EAGLE        77.881733                    7        1995.6
# 56   ASTON MARTIN        81.643416                    3        2014.0
#
#     weighted_inj_sev_rate
# 2               32.000000
# 3               28.700000
# 5               24.250000
# 6               24.187500
# 7               22.107018
# 8               21.605792
# 9               17.400000
# 10              17.863389
# 11              17.269411
# 12              15.398148
# 13              15.318065
# 14              15.044147
# 15              15.702461
# 16              15.560408
# 17              15.321247
# 18              15.107752
# 19              15.148926
# 20              15.246789
# 21              15.109261
# 22              14.767666
# 23              14.467593
# 24              14.879358
# 25              14.492508
# 26              14.264706
# 27              14.188690
# 28              14.084740
# 29              14.004913
# 30              13.935860
# 31              14.088266
# 32              14.063568
# 33              13.738548
# 34              13.500000
# 35              13.565616
# 36              13.717047
# 37              13.804752
# 38              13.292278
# 39              13.696487
# 40              13.102919
# 41              12.940980
# 42              12.962247
# 43              12.808267
# 44              12.455969
# 45              12.327497
# 46              11.983193
# 47              12.016393
# 48              11.563344
# 49              11.426039
# 50              10.429054
# 51              11.147667
# 52               9.849673
# 53               8.261905
# 56               3.000000

# %% [markdown]
# ** It is time to get 2017 and 2018 crash data and merge into a final crash file. I will use the same metrics created in this notebook for combined data for three years(2016, 2017, 2018). **

# %%
crash.to_csv('data/crash.csv', index=False)

# %%
print('This data includes ' + str(len(crash.casenum.unique())) + ' different accidents from years 2016, 2017 and 2018')
# Out:
# This data includes 118474 different accidents from years 2016, 2017 and 2018
